# %%
import pandas as pd


k=4

class Node:
  def __init__(self,data):
    self.data = data
    self.left = None
    self.right = None



  def insertNode(root,data,depth):

      if root is None:
         root = Node(data)
         return root

      cd = depth%k

      if data[cd]<root.data[cd]:
        root.left=x.insertNode(root.left,data,depth+1)
      else:
        root.right=x.insertNode(root.right,data,depth+1)

      return root



  def printdata(root,depth):
    if root is None:
       return None

    x.printdata(root.left,depth+1)
    print(root.data)
    x.printdata(root.right,depth+1)


if __name__=='__main__':


  data = pd.read_csv("dataset.csv")
  data = data.sort_values(by=[*data.columns])

  data = data.values.tolist()

  root = None
  x=Node

  for d in data:
    root = x.insertNode(root,d,0)

  x.printdata(root,0)
# Out:
# [10.0, 2.7, 5.0, 90992.0]
# [18.0, 3.9, 3.0, 43154.0]
# [46.0, 1.2, 2.0, 41198.0]
# [75.0, 1.4, 3.0, 42000.0]
# [90.0, 1.0, 3.0, 42000.0]
# [80.0, 0.5, 4.0, 45000.0]
# [85.0, 0.9, 4.0, 35000.0]
# [85.0, 1.1, 4.0, 42000.0]
# [75.0, 1.9, 4.0, 30000.0]
# [55.0, 0.6, 4.0, 50377.0]
# [70.0, 1.4, 4.0, 55000.0]
# [70.0, 1.8, 4.0, 55000.0]
# [70.0, 1.8, 4.0, 55000.0]
# [70.0, 2.0, 4.0, 55000.0]
# [70.0, 2.0, 4.0, 55000.0]
# [23.0, 2.5, 4.0, 43617.0]
# [26.0, 4.8, 2.0, 42678.0]
# [60.0, 3.0, 4.0, 38000.0]
# [80.0, 2.5, 4.0, 45000.0]
# [41.0, 2.6, 2.0, 45788.0]
# [45.0, 2.5, 3.0, 50922.0]
# [65.0, 2.6, 4.0, 48000.0]
# [65.0, 2.6, 4.0, 48000.0]
# [51.0, 4.8, 2.0, 55257.0]
# [12.0, 2.5, 4.0, 55682.0]
# [24.0, 2.3, 4.0, 103167.0]
# [80.0, 0.8, 2.0, 95000.0]
# [85.0, 0.7, 2.0, 90000.0]
# [85.0, 0.7, 2.0, 90000.0]
# [80.0, 0.8, 2.0, 95000.0]
# [57.0, 1.4, 2.0, 98930.0]
# [60.0, 0.8, 2.0, 120000.0]
# [80.0, 0.5, 2.0, 105000.0]
# [80.0, 0.5, 2.0, 105000.0]
# [80.0, 0.5, 2.0, 110000.0]
# ...
